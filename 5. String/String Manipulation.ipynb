# %%
# String Manipulation
print('hello world \nhello world \nhello world')
# Out:
# hello world
# hello world
# hello world

# %%
# Concatenation
print('hello' + 'shubham')
print('hello ' + 'shubham') # Giving space after hello
print('hello' + ' shubham') # Giving space before jenny
print('hello' + ' ' + 'shubham') # Giving a space between them bcz space is an individual string
# Out:
# helloshubham
# hello shubham
# hello shubham
# hello shubham

# %%
#Indentation Error(the space before start of code)   
    print('hello' + 'shubham')
# Out:
#   Cell In[3], line 2
#     print('hello' + 'shubham')
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # ASSIGNMENT

# %%
## print----

# String Manipulation Exercise
# String Concatenation is done with + sign
# e.g. print(hello + shubham )
# New lines can be created with a backslash and n

# %%
# solution


print('String Manipulation Exercise')
print('String Concatenation is done with "+" sign')
print('e.g. print("hello"+"shubham")')
print('New lines can be created with a backslash and n')
# Out:
# String Manipulation Exercise
# String Concatenation is done with "+" sign
# e.g. print("hello"+"shubham")
# New lines can be created with a backslash and n
